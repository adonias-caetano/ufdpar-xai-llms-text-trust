# %% [markdown]
# #  **Análise das respostas na escala Likert**
#
# **Authors:** Adonias Caetano de Oliveira, Ariel Soares Teles
#
# **Institution:** IFCE Campus Tianguá

# %% [markdown]
# ## **Library installation and environment configuration**

# %%
# !pip install plot-likert
# Out:
# Collecting plot-likert
#   Downloading plot_likert-0.5.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: matplotlib>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from plot-likert) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from plot-likert) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from plot-likert) (2.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.0->plot-likert) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.0->plot-likert) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.0->plot-likert) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.0->plot-likert) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.0->plot-likert) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.0->plot-likert) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.0->plot-likert) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.0->plot-likert) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->plot-likert) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->plot-likert) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4.0->plot-likert) (1.17.0)
# Downloading plot_likert-0.5.0-py3-none-any.whl (11 kB)
# Installing collected packages: plot-likert
# Successfully installed plot-likert-0.5.0

# %% [markdown]
# ## **Importing library**

# %%
# Auxiliaries
import pandas as pd
import numpy as np
import io
import re
import plot_likert

# %% [markdown]
# ## **Lendo o datasett**

# %%
url = '<link público google drive do dataset boamente no formato excel>'
file_id = url.split('/')[-2]
read_url='https://drive.google.com/uc?id=' + file_id

# read the data
df = pd.read_excel(read_url, sheet_name='respostas')
df
# Out:
#      Compreensão  Consistência  Relevância  Confiança
# 0              5             5           5          5
# 1              5             5           5          5
# 2              5             5           4          3
# 3              5             5           5          5
# 4              1             1           1          1
# ..           ...           ...         ...        ...
# 425            5             5           5          5
# 426            5             4           4          5
# 427            4             4           4          4
# 428            4             4           4          4
# 429            4             4           4          4
#
# [430 rows x 4 columns]

# %%
another_scale = ['Discordo Totalmente', 'Discordo Parcialmente', 'Neutro / Indiferente', 'Concordo Parcialmente', 'Concordo Totalmente']

# %%
df.replace({1: 'Discordo Totalmente', 2: 'Discordo Parcialmente', 3: 'Neutro / Indiferente', 4: 'Concordo Parcialmente', 5: 'Concordo Totalmente' },  inplace=True )

# %%
df
# Out:
#                Compreensão           Consistência             Relevância  \
# 0      Concordo Totalmente    Concordo Totalmente    Concordo Totalmente
# 1      Concordo Totalmente    Concordo Totalmente    Concordo Totalmente
# 2      Concordo Totalmente    Concordo Totalmente  Concordo Parcialmente
# 3      Concordo Totalmente    Concordo Totalmente    Concordo Totalmente
# 4      Discordo Totalmente    Discordo Totalmente    Discordo Totalmente
# ..                     ...                    ...                    ...
# 425    Concordo Totalmente    Concordo Totalmente    Concordo Totalmente
# 426    Concordo Totalmente  Concordo Parcialmente  Concordo Parcialmente
# 427  Concordo Parcialmente  Concordo Parcialmente  Concordo Parcialmente
# 428  Concordo Parcialmente  Concordo Parcialmente  Concordo Parcialmente
# 429  Concordo Parcialmente  Concordo Parcialmente  Concordo Parcialmente
#
#                  Confiança
# 0      Concordo Totalmente
# 1      Concordo Totalmente
# 2     Neutro / Indiferente
# 3      Concordo Totalmente
# 4      Discordo Totalmente
# ..                     ...
# 425    Concordo Totalmente
# 426    Concordo Totalmente
# 427  Concordo Parcialmente
# 428  Concordo Parcialmente
# 429  Concordo Parcialmente
#
# [430 rows x 4 columns]

# %%
plot_likert.plot_likert(df, another_scale,  figsize=(5,10), bar_labels=True, bar_labels_color="snow", colors=plot_likert.colors.default_with_darker_neutral);
# Out:
# /usr/local/lib/python3.12/dist-packages/plot_likert/plot_likert.py:257: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(validate)
